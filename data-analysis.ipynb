# %%
import pandas as pd

# %%
#read in json file
df = pd.read_json('data.json')

# %%
df
# Out:
#                            email  currentStep  duration logType  \
# 0     chuchuli@cs.washington.edu         11.0   105.254    temp
# 1         mishalehmann@gmail.com         34.0  8745.609    temp
# 2     chuchuli@cs.washington.edu         10.0   211.085    temp
# 3         mishalehmann@gmail.com         29.0  8669.066    temp
# 4         mishalehmann@gmail.com         26.0  8644.991    temp
# ..                           ...          ...       ...     ...
# 872       mishalehmann@gmail.com         22.0  8612.989    temp
# 873   chuchuli@cs.washington.edu         16.0   221.812    temp
# 874   chuchuli@cs.washington.edu         10.0   214.624    temp
# 875              chuchuli@uw.edu         15.0    25.891    temp
# 876  rittersdorfinskey@gmail.com         35.0   600.099    temp
#
#                       answeredMobilityAids  \
# 0    [Mobility scooter, Manual wheelchair]
# 1                                       []
# 2                       [Mobility scooter]
# ...

# %%
#select email == rittersdorfinskey@gmail.com and put into new dataframe
p0 = df[df['email'] == 'rittersdorfinskey@gmail.com']

# %%
p1 = df[df['email'] == 'mishalehmann@gmail.com']

# %%
p0['sidewalkBarriers'].unique()
# Out:
# array(['Cars parked over the curb, uneven sidewalks, and missing curb bumps',
#        "The most common barrier i see are people who's bumper goes over the sidewalk when parked (pickup trucks most often), missing curb bumps or curb bumps that don't full drop down, and sidewalks that are complete cracked and uneven.",
#        ''], dtype=object)

# %%
#check log type == final
p0[p0['logType'] == 'final']
# Out:
#                            email  currentStep  duration logType  \
# 210  rittersdorfinskey@gmail.com         38.0  1058.349   final
# 291  rittersdorfinskey@gmail.com         38.0  1053.961   final
#
#                                   answeredMobilityAids        mobilityAid  \
# 210  [Manual wheelchair, Manual wheelchair, Manual ...  Manual wheelchair
# 291             [Manual wheelchair, Manual wheelchair]  Manual wheelchair
#
#                                       sidewalkBarriers  hasDragged  \
# 210  Cars parked over the curb, uneven sidewalks, a...         1.0
# 291  Cars parked over the curb, uneven sidewalks, a...         1.0
#
#                                 sessionId              name  \
# 210  d4884470-70e8-4e5a-a822-6f8b3c829bad  Ewan Rittersdorf
# 291  d4884470-70e8-4e5a-a822-6f8b3c829bad  Ewan Rittersdorf
#
#                                     mobilityAidOptions  \
# 210  {'mobilityAidOptions': ['Walking cane', 'Manua...
# ...

# %%
print(p0['sidewalkBarriers'].unique())

# %%
#save p0 to csv
p0.to_csv('p0.csv', index=False)

# %%
p1.to_csv('p1.csv', index=False)

# %%
p1
# Out:
#                       email  currentStep  duration logType  \
# 1    mishalehmann@gmail.com         34.0  8745.609    temp
# 3    mishalehmann@gmail.com         29.0  8669.066    temp
# 4    mishalehmann@gmail.com         26.0  8644.991    temp
# 5    mishalehmann@gmail.com         29.0  8669.835    temp
# 12   mishalehmann@gmail.com         16.0   274.856    temp
# ..                      ...          ...       ...     ...
# 860  mishalehmann@gmail.com         13.0   218.335    temp
# 861  mishalehmann@gmail.com         12.0   207.204    temp
# 863  mishalehmann@gmail.com         22.0  8603.008    temp
# 869  mishalehmann@gmail.com         29.0  8682.791    temp
# 872  mishalehmann@gmail.com         22.0  8612.989    temp
#
#     answeredMobilityAids                                 mobilityAid  \
# 1                     []  Rollator/transport chair convertible combo
# 3                     []  Rollator/transport chair convertible combo
# ...
